# %% [markdown]
# # VocalSet VTC experiments

# %% [markdown]
# ## 1. Setup

# %%
import types, importlib, sys
imp = types.ModuleType("imp")
imp.reload = importlib.reload
sys.modules["imp"] = imp
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Experiments

# %% [markdown]
# #### Run a single block manually

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       2     resolved = resolve_dataset(
#       3         dataset, partition, ExperimentFilters(gender="mixed", include_labels="PMT"),
#       4         frame_duration=3.0, overlap=0.25,
#       5     )
# ----> 6     metrics = run_benchmark(resolved, trad_ml_benchmark, output_dir="./results/manual/pmt_mixed")
#       7     print(f"Done: {dataset.name}")
#
# TypeError: run_benchmark() got an unexpected keyword argument 'output_dir'
