# %% [markdown]
# # VocalSet VTC experiments

# %% [markdown]
# ## 1. Setup

# %%
import types, importlib, sys
imp = types.ModuleType("imp")
imp.reload = importlib.reload
sys.modules["imp"] = imp
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Experiments

# %%
from scripts.run_benchmark import run_experiment

results = run_experiment(
    "./vocalset_full_experiment.py"
)
# Out:
# Environment snapshot saved to metrics/vtc_vocalset_full/environment.txt
#
# ...
# Experiment: vtc_vocalset_full
# Blocks:     5
# ...
#
#
# ────────────────────────────────────────────────────────────
# Block 1: features
#   Benchmark: trad_ml
#   Models:    knn, rf, mlp, svm
#   Partition: vocalset_singer_independent
#   Datasets:  opensmile, vggish, whisper, clap, mfcc
#   Gender:    mixed
#   Labels:    10 classes
# ────────────────────────────────────────────────────────────
#
#
#   Dataset: opensmile
#   Model: knn
#   Completed: trad_ml/opensmile/knn
#   Model: rf
#   Completed: trad_ml/opensmile/rf
#   Model: mlp
#   Completed: trad_ml/opensmile/mlp
#   Model: svm
# /home/suvihaara/miniforge3/envs/benchmark_env_clean/lib/python3.12/site-packages/sklearn/svm/_base.py:239: FutureWarning: The `probability` parameter was deprecated in 1.9 and will be removed in version 1.11. Use `CalibratedClassifierCV(SVC(), ensemble=False)` instead of `SVC(probability=True)`
#   warnings.warn(
# ...

# %%
from scripts.run_benchmark import run_experiment

results = run_experiment(
    "./vocalset_full_experiment.py"
)
# Out:
# Environment snapshot saved to metrics/vtc_vocalset_full/environment.txt
#
# ...
# Experiment: vtc_vocalset_full
# Blocks:     1
# ...
#
#
# ────────────────────────────────────────────────────────────
# Block 1: features
#   Benchmark: trad_ml
#   Models:    knn, rf, mlp, svm
#   Partition: vocalset_singer_independent
#   Datasets:  opensmile, vggish, whisper, clap, mfcc
#   Gender:    mixed
#   Labels:    10 classes
# ────────────────────────────────────────────────────────────
#
#
#   Dataset: opensmile
#   Model: knn
#   Completed: trad_ml/opensmile/knn
#   Model: rf
#   Completed: trad_ml/opensmile/rf
#   Model: mlp
#   Completed: trad_ml/opensmile/mlp
#   Model: svm
# /home/suvihaara/miniforge3/envs/benchmark_env_clean/lib/python3.12/site-packages/sklearn/svm/_base.py:239: FutureWarning: The `probability` parameter was deprecated in 1.9 and will be removed in version 1.11. Use `CalibratedClassifierCV(SVC(), ensemble=False)` instead of `SVC(probability=True)`
#   warnings.warn(
# ...
