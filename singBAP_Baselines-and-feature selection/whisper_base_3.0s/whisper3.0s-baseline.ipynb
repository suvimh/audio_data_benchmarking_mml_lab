# %%
import time
import numpy as np
import pandas as pd

from sklearn.base import clone
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
)

# %%
DATASET_NAME = "Whisper Base 3.0s"

DATASET_PATH = (
    "/Users/bhavaykhatri/Desktop/whisper_base/"
    "singBAP_dataset_whisper_whisper-base_3.0s.parquet"
)

df = pd.read_parquet(DATASET_PATH)

print("Shape:", df.shape)
print("Columns:", df.columns.tolist())

df.head()
# Out:
# Shape: (4116, 13)
# Columns: ['condition', 'experience', 'extractor', 'filename', 'filepath', 'frame_index', 'phonation', 'scale', 'singer', 'take', 'embedding', 'embedding_dtype', 'embedding_shape']
#            condition     experience             extractor  \
# 0  after_instruction  inexperienced  whisper_whisper-base
# 1  after_instruction  inexperienced  whisper_whisper-base
# 2  after_instruction  inexperienced  whisper_whisper-base
# 3  after_instruction  inexperienced  whisper_whisper-base
# 4  after_instruction  inexperienced  whisper_whisper-base
#
#                                          filename  \
# 0  inex-1-after_instruction-glissando-1-mic-audio
# 1  inex-1-after_instruction-glissando-2-mic-audio
# 2  inex-1-after_instruction-glissando-2-mic-audio
# 3  inex-1-after_instruction-glissando-3-mic-audio
# 4  inex-1-after_instruction-glissando-3-mic-audio
#
#                                             filepath  frame_index phonation  \
# 0  /home/suvihaara/Documents/PhD/DATA/VTE/SingBAP...            0
# 1  /home/suvihaara/Documents/PhD/DATA/VTE/SingBAP...            0
# 2  /home/suvihaara/Documents/PhD/DATA/VTE/SingBAP...            1
# 3  /home/suvihaara/Documents/PhD/DATA/VTE/SingBAP...            0
# 4  /home/suvihaara/Documents/PhD/DATA/VTE/SingBAP...            1
#
#        scale  singer take                                          embedding  \
# 0  glissando  INEX-1    1  b'\x07\x9dU\xbe\xecA(\xbfX\xf9Q>J\x82\x8e\xbfg...
# 1  glissando  INEX-1    2  b'Z\xaee\xbe\x12\xbc)\xbf\x0c\xc45>\xe1\x82\x8...
# 2  glissando  INEX-1    2  b'\xc1=\x0b\xbd2m\x1b\xbfw2\xa0>\x9f\xfdk\xbf\...
# 3  glissando  INEX-1    3  b'\xc6]x\xbe\xf2\x82\x1e\xbf\xfdS>>\x83\x00\x8...
# 4  glissando  INEX-1    3  b'\x99\xea\x15\xbe?\xa81\xbf\x15\xc7U>\x80`\x8...
#
#   embedding_dtype embedding_shape
# 0             <f4           [512]
# 1             <f4           [512]
# 2             <f4           [512]
# 3             <f4           [512]
# 4             <f4           [512]

# %%
TARGET_CLASSES = [
    "correct",
    "arched_back",
    "hunched_back",
    "sideways",
    "chest_breathing",
    "over_articulation",
    "under_articulation",
]

df = df[
    df["experience"].isin(
        ["intermediate", "professional"]
    )
].copy()

df = df[
    df["condition"].isin(TARGET_CLASSES)
].copy()

print("Filtered shape:", df.shape)
print(df["condition"].value_counts())
print(df["experience"].value_counts())
# Out:
# Filtered shape: (3438, 13)
# condition
# correct               638
# hunched_back          556
# sideways              521
# chest_breathing       512
# over_articulation     411
# arched_back           405
# under_articulation    395
# Name: count, dtype: int64
# experience
# intermediate    2794
# professional     644
# Name: count, dtype: int64

# %%
def decode_embedding(value):
    if isinstance(
        value,
        (bytes, bytearray, memoryview),
    ):
        return np.frombuffer(
            value,
            dtype=np.float32,
        ).copy()

    return np.asarray(
        value,
        dtype=np.float32,
    ).reshape(-1)

# %%
X = np.vstack(
    df["embedding"].apply(decode_embedding)
)

y = df["condition"].astype(str).to_numpy()

groups = df["filename"].astype(str).to_numpy()

print("X shape:", X.shape)
print("y shape:", y.shape)
print("Unique recordings:", len(np.unique(groups)))
# Out:
# X shape: (3438, 512)
# y shape: (3438,)
# Unique recordings: 3046

# %%
splitter = StratifiedGroupKFold(
    n_splits=5,
    shuffle=True,
    random_state=42,
)

train_idx, test_idx = next(
    splitter.split(
        X,
        y,
        groups=groups,
    )
)

X_train = X[train_idx]
X_test = X[test_idx]

y_train = y[train_idx]
y_test = y[test_idx]

train_groups = groups[train_idx]
test_groups = groups[test_idx]

print("Train:", X_train.shape)
print("Test:", X_test.shape)

print(
    "Shared recordings:",
    len(
        set(train_groups)
        & set(test_groups)
    ),
)
# Out:
# Train: (2750, 512)
# Test: (688, 512)
# Shared recordings: 0

# %%
MODELS = {
    "MLP": make_pipeline(
        StandardScaler(),
        MLPClassifier(
            hidden_layer_sizes=(256, 128),
            early_stopping=True,
            max_iter=300,
            random_state=42,
        ),
    ),

    "KNN": make_pipeline(
        StandardScaler(),
        KNeighborsClassifier(
            n_neighbors=15,
            metric="cosine",
            n_jobs=-1,
        ),
    ),

    "Random Forest": RandomForestClassifier(
        n_estimators=300,
        class_weight="balanced",
        random_state=42,
        n_jobs=-1,
    ),

    "Linear SVM": make_pipeline(
        StandardScaler(),
        LinearSVC(
            class_weight="balanced",
            max_iter=10000,
            random_state=42,
        ),
    ),
}

# %%
results = []

for model_name, base_model in MODELS.items():
    print(f"Training {model_name}...")

    model = clone(base_model)

    start = time.time()

    model.fit(
        X_train,
        y_train,
    )

    predictions = model.predict(
        X_test
    )

    elapsed = time.time() - start

    results.append({
        "Embedding": DATASET_NAME,
        "Model": model_name,

        "Accuracy": round(
            accuracy_score(
                y_test,
                predictions,
            ),
            4,
        ),

        "Balanced Accuracy": round(
            balanced_accuracy_score(
                y_test,
                predictions,
            ),
            4,
        ),

        "Macro F1": round(
            f1_score(
                y_test,
                predictions,
                average="macro",
                zero_division=0,
            ),
            4,
        ),

        "Train/Eval Time (s)": round(
            elapsed,
            2,
        ),

        "Samples": len(y),
        "Features": X.shape[1],
    })
# Out:
# Training MLP...
# Training KNN...
# Training Random Forest...
# Training Linear SVM...

# %%
results_df = pd.DataFrame(results)

results_df = results_df.sort_values(
    "Macro F1",
    ascending=False,
).reset_index(drop=True)

results_df
# Out:
#            Embedding          Model  Accuracy  Balanced Accuracy  Macro F1  \
# 0  Whisper Base 3.0s            MLP    0.4927             0.5031    0.5001
# 1  Whisper Base 3.0s     Linear SVM    0.4375             0.4481    0.4453
# 2  Whisper Base 3.0s  Random Forest    0.4172             0.4292    0.4205
# 3  Whisper Base 3.0s            KNN    0.3241             0.3244    0.3301
#
#    Train/Eval Time (s)  Samples  Features
# 0                 1.87     3438       512
# 1                 4.29     3438       512
# 2                 1.45     3438       512
# 3                 0.11     3438       512

# %%
results_df.to_csv(
    "whisper_base_3.0s_baseline.csv",
    index=False,
)

print("Saved: whisper_base_3.0s_baseline.csv")
# Out:
# Saved: whisper_base_3.0s_baseline.csv
