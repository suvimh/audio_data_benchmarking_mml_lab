# %%
import time
import numpy as np
import pandas as pd

from sklearn.base import clone
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
)

# %%
DATASET_NAME = "CLAP 3.0s"

DATASET_PATH = (
    "/Users/bhavaykhatri/Desktop/msclap_2023/"
    "singBAP_dataset_clap-2023_3.0s.parquet"
)

df = pd.read_parquet(DATASET_PATH)

print("Shape:", df.shape)
print("Columns:", df.columns.tolist())

df.head()
# Out:
# Shape: (4116, 13)
# Columns: ['condition', 'experience', 'extractor', 'filename', 'filepath', 'frame_index', 'phonation', 'scale', 'singer', 'take', 'embedding', 'embedding_dtype', 'embedding_shape']
#            condition     experience  extractor  \
# 0  after_instruction  inexperienced  clap-2023
# 1  after_instruction  inexperienced  clap-2023
# 2  after_instruction  inexperienced  clap-2023
# 3  after_instruction  inexperienced  clap-2023
# 4  after_instruction  inexperienced  clap-2023
#
#                                          filename  \
# 0  inex-1-after_instruction-glissando-1-mic-audio
# 1  inex-1-after_instruction-glissando-2-mic-audio
# 2  inex-1-after_instruction-glissando-2-mic-audio
# 3  inex-1-after_instruction-glissando-3-mic-audio
# 4  inex-1-after_instruction-glissando-3-mic-audio
#
#                                             filepath  frame_index phonation  \
# 0  /home/suvihaara/Documents/PhD/DATA/VTE/SingBAP...            0
# 1  /home/suvihaara/Documents/PhD/DATA/VTE/SingBAP...            0
# 2  /home/suvihaara/Documents/PhD/DATA/VTE/SingBAP...            1
# 3  /home/suvihaara/Documents/PhD/DATA/VTE/SingBAP...            0
# 4  /home/suvihaara/Documents/PhD/DATA/VTE/SingBAP...            1
#
#        scale  singer take                                          embedding  \
# 0  glissando  INEX-1    1  b'\xf3\x13A\xbf\xec\x13\xb6\xbe\'\x08\xbe>v<%?...
# 1  glissando  INEX-1    2  b'`yO\xbf\xe2\x0b\xff\xbe<\xdf\x80?\\.\x9a?\x1...
# 2  glissando  INEX-1    2  b'.\\\xeb\xbes1\xeb\xbe\x1f\x8au?\x9a\xcb\x90?...
# 3  glissando  INEX-1    3  b'\xf6C\xc4\xbe\xceB\xeb:w\xb8\x98?\xc7yw?(\x8...
# 4  glissando  INEX-1    3  b'\xde\xac\xd7\xben\xf6\x06\xbf\x1cp\xa3?lF}?\...
#
#   embedding_dtype embedding_shape
# 0             <f4          [1024]
# 1             <f4          [1024]
# 2             <f4          [1024]
# 3             <f4          [1024]
# 4             <f4          [1024]

# %%
TARGET_CLASSES = [
    "correct",
    "arched_back",
    "hunched_back",
    "sideways",
    "chest_breathing",
    "over_articulation",
    "under_articulation",
]

df = df[
    df["experience"].isin(
        ["intermediate", "professional"]
    )
].copy()

df = df[
    df["condition"].isin(TARGET_CLASSES)
].copy()

print("Filtered shape:", df.shape)
print(df["condition"].value_counts())
print(df["experience"].value_counts())
# Out:
# Filtered shape: (3438, 13)
# condition
# correct               638
# hunched_back          556
# sideways              521
# chest_breathing       512
# over_articulation     411
# arched_back           405
# under_articulation    395
# Name: count, dtype: int64
# experience
# intermediate    2794
# professional     644
# Name: count, dtype: int64

# %%
def decode_embedding(value):
    if isinstance(
        value,
        (bytes, bytearray, memoryview),
    ):
        return np.frombuffer(
            value,
            dtype=np.float32,
        ).copy()

    return np.asarray(
        value,
        dtype=np.float32,
    ).reshape(-1)

# %%
X = np.vstack(
    df["embedding"].apply(decode_embedding)
)

y = df["condition"].astype(str).to_numpy()

groups = df["filename"].astype(str).to_numpy()

print("X shape:", X.shape)
print("y shape:", y.shape)
print("Unique recordings:", len(np.unique(groups)))
# Out:
# X shape: (3438, 1024)
# y shape: (3438,)
# Unique recordings: 3046

# %%
splitter = StratifiedGroupKFold(
    n_splits=5,
    shuffle=True,
    random_state=42,
)

train_idx, test_idx = next(
    splitter.split(
        X,
        y,
        groups=groups,
    )
)

X_train = X[train_idx]
X_test = X[test_idx]

y_train = y[train_idx]
y_test = y[test_idx]

train_groups = groups[train_idx]
test_groups = groups[test_idx]

print("Train:", X_train.shape)
print("Test:", X_test.shape)

print(
    "Shared recordings:",
    len(
        set(train_groups)
        & set(test_groups)
    ),
)
# Out:
# Train: (2750, 1024)
# Test: (688, 1024)
# Shared recordings: 0

# %%
MODELS = {
    "MLP": make_pipeline(
        StandardScaler(),
        MLPClassifier(
            hidden_layer_sizes=(256, 128),
            early_stopping=True,
            max_iter=300,
            random_state=42,
        ),
    ),

    "KNN": make_pipeline(
        StandardScaler(),
        KNeighborsClassifier(
            n_neighbors=15,
            metric="cosine",
            n_jobs=-1,
        ),
    ),

    "Random Forest": RandomForestClassifier(
        n_estimators=300,
        class_weight="balanced",
        random_state=42,
        n_jobs=-1,
    ),

    "Linear SVM": make_pipeline(
        StandardScaler(),
        LinearSVC(
            class_weight="balanced",
            max_iter=10000,
            random_state=42,
        ),
    ),
}

# %%
results = []

for model_name, base_model in MODELS.items():
    print(f"Training {model_name}...")

    model = clone(base_model)

    start = time.time()

    model.fit(
        X_train,
        y_train,
    )

    predictions = model.predict(
        X_test
    )

    elapsed = time.time() - start

    results.append({
        "Embedding": DATASET_NAME,
        "Model": model_name,

        "Accuracy": round(
            accuracy_score(
                y_test,
                predictions,
            ),
            4,
        ),

        "Balanced Accuracy": round(
            balanced_accuracy_score(
                y_test,
                predictions,
            ),
            4,
        ),

        "Macro F1": round(
            f1_score(
                y_test,
                predictions,
                average="macro",
                zero_division=0,
            ),
            4,
        ),

        "Train/Eval Time (s)": round(
            elapsed,
            2,
        ),

        "Samples": len(y),
        "Features": X.shape[1],
    })
# Out:
# Training MLP...
# Training KNN...
# Training Random Forest...
# Training Linear SVM...

# %%
results_df = pd.DataFrame(results)

results_df = results_df.sort_values(
    "Macro F1",
    ascending=False,
).reset_index(drop=True)

results_df
# Out:
#    Embedding          Model  Accuracy  Balanced Accuracy  Macro F1  \
# 0  CLAP 3.0s            MLP    0.5247             0.5204    0.5301
# 1  CLAP 3.0s     Linear SVM    0.4695             0.4707    0.4714
# 2  CLAP 3.0s  Random Forest    0.4564             0.4631    0.4586
# 3  CLAP 3.0s            KNN    0.3154             0.3139    0.3186
#
#    Train/Eval Time (s)  Samples  Features
# 0                 3.50     3438      1024
# 1                17.61     3438      1024
# 2                 2.14     3438      1024
# 3                 0.19     3438      1024

# %%
results_df.to_csv(
    "clap_3.0s_baseline.csv",
    index=False,
)

print("Saved: clap_3.0s_baseline.csv")
# Out:
# Saved: clap_3.0s_baseline.csv
